# %%
# %pip install ultralytics pandas openpyxl
# Out:
# Requirement already satisfied: ultralytics in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (8.3.113)
# Requirement already satisfied: pandas in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (3.1.5)
# Requirement already satisfied: opencv-python>=4.6.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pyyaml>=5.3.1 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: py-cpuinfo in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: psutil in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (2.1.1)
# Requirement already satisfied: tqdm>=4.64.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: torch>=1.8.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: pillow>=7.1.2 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: torchvision>=0.9.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: requests>=2.23.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: seaborn>=0.11.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: matplotlib>=3.3.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: scipy>=1.4.1 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: tzdata>=2022.7 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: fonttools>=4.22.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: contourpy>=1.0.1 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: six>=1.5 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: fsspec in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: jinja2 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: filelock in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: sympy==1.13.1 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in s:\deeplearning-inholland\sheep-detector\venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
import pandas

# %%
ROOT_FOLDER = ".."
DATASET_FOLDER = f"{ROOT_FOLDER}/dataset"
MODEL_FOLDER = f"{ROOT_FOLDER}/model"
RUNS_FOLDER = f"{ROOT_FOLDER}/runs"

BASE_MODEL = 'yolo11n.pt'

# %%
search_space = {
    "lr0": (1e-5, 1e-1),         # Learning Rate
    "momentum": (0.6, 0.98),     # Momentum
    "weight_decay": (0.0, 0.001),# Weight Decay
    "warmup_epochs": (0.0, 5.0), # Warmup Epochs
    "box": (0.02, 0.2),          # Box Loss
    "cls": (0.2, 4.0),           # Classification Loss
}

model = YOLO(f"{MODEL_FOLDER}/{BASE_MODEL}")

# %%
result_grid = model.tune(
    data="sheep.yaml", 
    epochs=5,          
    iterations=50,             
    space=search_space,       
    single_cls=True,          
    patience=5,         
    verbose=True,
    device=0
)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3'
# Tuner:  Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/50 with hyperparameters: {'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'box': 0.2, 'cls': 0.5}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 1/50 iterations complete  (94.28s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.10989 observed at iteration 1
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.3597, 'metrics/mAP50-95(B)': 0.08214, 'val/box_loss': 0.0642, 'val/cls_loss': 3.84057, 'val/dfl_loss': 1.30297, 'fitness': 0.10989}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train20
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# box: 0.2
# cls: 0.5
#
# Tuner: Starting iteration 2/50 with hyperparameters: {'lr0': 0.00911, 'momentum': 0.88473, 'weight_decay': 0.0005, 'warmup_epochs': 2.34777, 'box': 0.2, 'cls': 0.48249}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 2/50 iterations complete  (187.16s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.118 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.0088, 'metrics/recall(B)': 0.77869, 'metrics/mAP50(B)': 0.38746, 'metrics/mAP50-95(B)': 0.08806, 'val/box_loss': 0.06454, 'val/cls_loss': 3.7061, 'val/dfl_loss': 1.30524, 'fitness': 0.118}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train21
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00911
# momentum: 0.88473
# weight_decay: 0.0005
# warmup_epochs: 2.34777
# box: 0.2
# cls: 0.48249
#
# Tuner: Starting iteration 3/50 with hyperparameters: {'lr0': 0.00894, 'momentum': 0.86071, 'weight_decay': 0.0005, 'warmup_epochs': 2.34777, 'box': 0.2, 'cls': 0.48132}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 3/50 iterations complete  (280.39s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.118 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.0088, 'metrics/recall(B)': 0.77869, 'metrics/mAP50(B)': 0.38746, 'metrics/mAP50-95(B)': 0.08806, 'val/box_loss': 0.06454, 'val/cls_loss': 3.7061, 'val/dfl_loss': 1.30524, 'fitness': 0.118}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train21
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00911
# momentum: 0.88473
# weight_decay: 0.0005
# warmup_epochs: 2.34777
# box: 0.2
# cls: 0.48249
#
# Tuner: Starting iteration 4/50 with hyperparameters: {'lr0': 0.00937, 'momentum': 0.87675, 'weight_decay': 0.00048, 'warmup_epochs': 2.35988, 'box': 0.2, 'cls': 0.47903}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 4/50 iterations complete  (373.40s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.118 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.0088, 'metrics/recall(B)': 0.77869, 'metrics/mAP50(B)': 0.38746, 'metrics/mAP50-95(B)': 0.08806, 'val/box_loss': 0.06454, 'val/cls_loss': 3.7061, 'val/dfl_loss': 1.30524, 'fitness': 0.118}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train21
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00911
# momentum: 0.88473
# weight_decay: 0.0005
# warmup_epochs: 2.34777
# box: 0.2
# cls: 0.48249
#
# Tuner: Starting iteration 5/50 with hyperparameters: {'lr0': 0.00772, 'momentum': 0.6555, 'weight_decay': 0.00057, 'warmup_epochs': 1.99371, 'box': 0.2, 'cls': 0.4504}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 5/50 iterations complete  (466.10s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.118 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.0088, 'metrics/recall(B)': 0.77869, 'metrics/mAP50(B)': 0.38746, 'metrics/mAP50-95(B)': 0.08806, 'val/box_loss': 0.06454, 'val/cls_loss': 3.7061, 'val/dfl_loss': 1.30524, 'fitness': 0.118}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train21
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00911
# momentum: 0.88473
# weight_decay: 0.0005
# warmup_epochs: 2.34777
# box: 0.2
# cls: 0.48249
#
# Tuner: Starting iteration 6/50 with hyperparameters: {'lr0': 0.00937, 'momentum': 0.98, 'weight_decay': 0.00047, 'warmup_epochs': 2.45659, 'box': 0.2, 'cls': 0.44728}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 6/50 iterations complete  (558.37s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.118 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.0088, 'metrics/recall(B)': 0.77869, 'metrics/mAP50(B)': 0.38746, 'metrics/mAP50-95(B)': 0.08806, 'val/box_loss': 0.06454, 'val/cls_loss': 3.7061, 'val/dfl_loss': 1.30524, 'fitness': 0.118}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train21
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00911
# momentum: 0.88473
# weight_decay: 0.0005
# warmup_epochs: 2.34777
# box: 0.2
# cls: 0.48249
#
# Tuner: Starting iteration 7/50 with hyperparameters: {'lr0': 0.01024, 'momentum': 0.97855, 'weight_decay': 0.00051, 'warmup_epochs': 1.94963, 'box': 0.2, 'cls': 0.31597}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 7/50 iterations complete  (650.60s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.118 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.0088, 'metrics/recall(B)': 0.77869, 'metrics/mAP50(B)': 0.38746, 'metrics/mAP50-95(B)': 0.08806, 'val/box_loss': 0.06454, 'val/cls_loss': 3.7061, 'val/dfl_loss': 1.30524, 'fitness': 0.118}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train21
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00911
# momentum: 0.88473
# weight_decay: 0.0005
# warmup_epochs: 2.34777
# box: 0.2
# cls: 0.48249
#
# Tuner: Starting iteration 8/50 with hyperparameters: {'lr0': 0.00911, 'momentum': 0.88473, 'weight_decay': 0.0005, 'warmup_epochs': 2.54015, 'box': 0.2, 'cls': 0.48249}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 8/50 iterations complete  (742.88s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.118 observed at iteration 2
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.0088, 'metrics/recall(B)': 0.77869, 'metrics/mAP50(B)': 0.38746, 'metrics/mAP50-95(B)': 0.08806, 'val/box_loss': 0.06454, 'val/cls_loss': 3.7061, 'val/dfl_loss': 1.30524, 'fitness': 0.118}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train21
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00911
# momentum: 0.88473
# weight_decay: 0.0005
# warmup_epochs: 2.34777
# box: 0.2
# cls: 0.48249
#
# Tuner: Starting iteration 9/50 with hyperparameters: {'lr0': 0.00949, 'momentum': 0.86071, 'weight_decay': 0.00048, 'warmup_epochs': 2.18848, 'box': 0.16628, 'cls': 0.46895}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 9/50 iterations complete  (835.31s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 10/50 with hyperparameters: {'lr0': 0.01001, 'momentum': 0.93134, 'weight_decay': 0.00039, 'warmup_epochs': 2.18848, 'box': 0.2, 'cls': 0.44664}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 10/50 iterations complete  (928.16s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 11/50 with hyperparameters: {'lr0': 0.00951, 'momentum': 0.86071, 'weight_decay': 0.00049, 'warmup_epochs': 2.19326, 'box': 0.16628, 'cls': 0.48061}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 11/50 iterations complete  (1021.07s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 12/50 with hyperparameters: {'lr0': 0.00859, 'momentum': 0.85088, 'weight_decay': 0.00055, 'warmup_epochs': 2.38843, 'box': 0.2, 'cls': 0.48249}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 12/50 iterations complete  (1113.38s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 13/50 with hyperparameters: {'lr0': 0.00948, 'momentum': 0.87922, 'weight_decay': 0.00047, 'warmup_epochs': 2.13504, 'box': 0.16531, 'cls': 0.47176}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 13/50 iterations complete  (1206.29s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 14/50 with hyperparameters: {'lr0': 0.00774, 'momentum': 0.86071, 'weight_decay': 0.00052, 'warmup_epochs': 2.58667, 'box': 0.16306, 'cls': 0.53139}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 14/50 iterations complete  (1298.09s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 15/50 with hyperparameters: {'lr0': 0.00979, 'momentum': 0.88004, 'weight_decay': 0.00054, 'warmup_epochs': 1.95353, 'box': 0.16628, 'cls': 0.47328}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 15/50 iterations complete  (1389.46s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 16/50 with hyperparameters: {'lr0': 0.00949, 'momentum': 0.96091, 'weight_decay': 0.00045, 'warmup_epochs': 2.20019, 'box': 0.12917, 'cls': 0.46895}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 16/50 iterations complete  (1480.78s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 17/50 with hyperparameters: {'lr0': 0.00949, 'momentum': 0.85455, 'weight_decay': 0.00045, 'warmup_epochs': 2.03988, 'box': 0.19025, 'cls': 0.49342}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 17/50 iterations complete  (1572.29s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 18/50 with hyperparameters: {'lr0': 0.00967, 'momentum': 0.98, 'weight_decay': 0.00053, 'warmup_epochs': 2.23802, 'box': 0.12917, 'cls': 0.56331}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 18/50 iterations complete  (1663.41s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 19/50 with hyperparameters: {'lr0': 0.00787, 'momentum': 0.86071, 'weight_decay': 0.00038, 'warmup_epochs': 1.84138, 'box': 0.16628, 'cls': 0.25886}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 19/50 iterations complete  (1754.83s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 20/50 with hyperparameters: {'lr0': 0.01216, 'momentum': 0.82794, 'weight_decay': 0.00043, 'warmup_epochs': 2.75509, 'box': 0.16628, 'cls': 0.57513}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 20/50 iterations complete  (1847.19s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 21/50 with hyperparameters: {'lr0': 0.00844, 'momentum': 0.98, 'weight_decay': 0.00048, 'warmup_epochs': 2.18848, 'box': 0.17075, 'cls': 0.51445}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 21/50 iterations complete  (1938.98s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 22/50 with hyperparameters: {'lr0': 0.00946, 'momentum': 0.96091, 'weight_decay': 0.00048, 'warmup_epochs': 2.4108, 'box': 0.11998, 'cls': 0.44853}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 22/50 iterations complete  (2030.66s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 23/50 with hyperparameters: {'lr0': 0.00852, 'momentum': 0.98, 'weight_decay': 0.00049, 'warmup_epochs': 2.69856, 'box': 0.1303, 'cls': 0.35848}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 23/50 iterations complete  (2121.65s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 24/50 with hyperparameters: {'lr0': 0.0121, 'momentum': 0.98, 'weight_decay': 0.00048, 'warmup_epochs': 2.18848, 'box': 0.15542, 'cls': 0.56335}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 24/50 iterations complete  (2213.10s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 25/50 with hyperparameters: {'lr0': 0.00949, 'momentum': 0.86071, 'weight_decay': 0.00048, 'warmup_epochs': 2.20817, 'box': 0.16644, 'cls': 0.47072}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 25/50 iterations complete  (2304.10s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 26/50 with hyperparameters: {'lr0': 0.00907, 'momentum': 0.86071, 'weight_decay': 0.00043, 'warmup_epochs': 2.28867, 'box': 0.15627, 'cls': 0.44737}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 26/50 iterations complete  (2394.62s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 27/50 with hyperparameters: {'lr0': 0.00949, 'momentum': 0.98, 'weight_decay': 0.00054, 'warmup_epochs': 1.89775, 'box': 0.09791, 'cls': 0.32457}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 27/50 iterations complete  (2485.69s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 28/50 with hyperparameters: {'lr0': 0.00995, 'momentum': 0.78378, 'weight_decay': 0.00046, 'warmup_epochs': 2.42534, 'box': 0.16633, 'cls': 0.46895}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 28/50 iterations complete  (2576.69s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 29/50 with hyperparameters: {'lr0': 0.00877, 'momentum': 0.6909, 'weight_decay': 0.00052, 'warmup_epochs': 2.13437, 'box': 0.16628, 'cls': 0.42705}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 29/50 iterations complete  (2667.23s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 30/50 with hyperparameters: {'lr0': 0.00912, 'momentum': 0.70685, 'weight_decay': 0.00053, 'warmup_epochs': 2.20019, 'box': 0.17551, 'cls': 0.47092}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 30/50 iterations complete  (2758.66s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 31/50 with hyperparameters: {'lr0': 0.00985, 'momentum': 0.81806, 'weight_decay': 0.00051, 'warmup_epochs': 2.09001, 'box': 0.16316, 'cls': 0.43415}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 31/50 iterations complete  (2850.42s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 32/50 with hyperparameters: {'lr0': 0.00964, 'momentum': 0.7911, 'weight_decay': 0.00047, 'warmup_epochs': 2.18848, 'box': 0.17408, 'cls': 0.48735}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 32/50 iterations complete  (2952.53s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 33/50 with hyperparameters: {'lr0': 0.01023, 'momentum': 0.61256, 'weight_decay': 0.0005, 'warmup_epochs': 2.43433, 'box': 0.2, 'cls': 0.56357}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 33/50 iterations complete  (3043.23s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 34/50 with hyperparameters: {'lr0': 0.0112, 'momentum': 0.72163, 'weight_decay': 0.00054, 'warmup_epochs': 2.20019, 'box': 0.1785, 'cls': 0.47512}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 34/50 iterations complete  (3134.06s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 35/50 with hyperparameters: {'lr0': 0.00744, 'momentum': 0.72163, 'weight_decay': 0.00055, 'warmup_epochs': 2.46571, 'box': 0.18799, 'cls': 0.51371}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 35/50 iterations complete  (3225.08s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 36/50 with hyperparameters: {'lr0': 0.00776, 'momentum': 0.76279, 'weight_decay': 0.00051, 'warmup_epochs': 2.20019, 'box': 0.17551, 'cls': 0.47092}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 36/50 iterations complete  (3317.42s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 37/50 with hyperparameters: {'lr0': 0.00954, 'momentum': 0.84197, 'weight_decay': 0.00047, 'warmup_epochs': 2.13863, 'box': 0.16628, 'cls': 0.46895}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 37/50 iterations complete  (3409.04s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 38/50 with hyperparameters: {'lr0': 0.00989, 'momentum': 0.85184, 'weight_decay': 0.00048, 'warmup_epochs': 1.95423, 'box': 0.1612, 'cls': 0.46895}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 38/50 iterations complete  (3500.08s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 39/50 with hyperparameters: {'lr0': 0.00863, 'momentum': 0.84197, 'weight_decay': 0.00046, 'warmup_epochs': 2.13863, 'box': 0.16943, 'cls': 0.46895}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 39/50 iterations complete  (3591.08s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 40/50 with hyperparameters: {'lr0': 0.0093, 'momentum': 0.87349, 'weight_decay': 0.00048, 'warmup_epochs': 2.17058, 'box': 0.16562, 'cls': 0.45621}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 40/50 iterations complete  (3682.27s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 41/50 with hyperparameters: {'lr0': 0.0107, 'momentum': 0.84197, 'weight_decay': 0.00053, 'warmup_epochs': 1.95672, 'box': 0.16628, 'cls': 0.49103}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 41/50 iterations complete  (3772.83s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 42/50 with hyperparameters: {'lr0': 0.00944, 'momentum': 0.86435, 'weight_decay': 0.00048, 'warmup_epochs': 2.12067, 'box': 0.165, 'cls': 0.48697}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 42/50 iterations complete  (3863.68s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 43/50 with hyperparameters: {'lr0': 0.00949, 'momentum': 0.86071, 'weight_decay': 0.00048, 'warmup_epochs': 2.16304, 'box': 0.16717, 'cls': 0.54345}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 43/50 iterations complete  (3954.59s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 44/50 with hyperparameters: {'lr0': 0.00995, 'momentum': 0.89181, 'weight_decay': 0.00048, 'warmup_epochs': 2.12984, 'box': 0.15672, 'cls': 0.46895}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 44/50 iterations complete  (4045.86s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 45/50 with hyperparameters: {'lr0': 0.00733, 'momentum': 0.76814, 'weight_decay': 0.00053, 'warmup_epochs': 2.50825, 'box': 0.17581, 'cls': 0.46895}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 45/50 iterations complete  (4137.15s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 46/50 with hyperparameters: {'lr0': 0.01185, 'momentum': 0.72163, 'weight_decay': 0.00054, 'warmup_epochs': 2.20019, 'box': 0.16078, 'cls': 0.36536}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 46/50 iterations complete  (4228.07s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 47/50 with hyperparameters: {'lr0': 0.00878, 'momentum': 0.84197, 'weight_decay': 0.00051, 'warmup_epochs': 1.86984, 'box': 0.2, 'cls': 0.46895}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 47/50 iterations complete  (4319.73s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 48/50 with hyperparameters: {'lr0': 0.00896, 'momentum': 0.84197, 'weight_decay': 0.00047, 'warmup_epochs': 2.13863, 'box': 0.14755, 'cls': 0.50053}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 48/50 iterations complete  (4410.78s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 49/50 with hyperparameters: {'lr0': 0.01029, 'momentum': 0.88282, 'weight_decay': 0.00048, 'warmup_epochs': 2.18848, 'box': 0.16628, 'cls': 0.45782}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 49/50 iterations complete  (4502.61s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895
#
# Tuner: Starting iteration 50/50 with hyperparameters: {'lr0': 0.00995, 'momentum': 0.79653, 'weight_decay': 0.00047, 'warmup_epochs': 2.48347, 'box': 0.16628, 'cls': 0.45441}
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_scatter_plots.png
# Saved s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\tune_fitness.png
#
# Tuner: 50/50 iterations complete  (4593.81s)
# Tuner: Results saved to s:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3
# Tuner: Best fitness=0.12254 observed at iteration 9
# Tuner: Best fitness metrics are {'metrics/precision(B)': 0.00889, 'metrics/recall(B)': 0.78689, 'metrics/mAP50(B)': 0.37402, 'metrics/mAP50-95(B)': 0.0946, 'val/box_loss': 0.05355, 'val/cls_loss': 3.60528, 'val/dfl_loss': 1.30441, 'fitness': 0.12254}
# Tuner: Best fitness model is s:\Deeplearning-inholland\Sheep-Detector\runs\detect\train28
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 's:\Deeplearning-inholland\Sheep-Detector\runs\detect\tune3\best_hyperparameters.yaml'
#
# lr0: 0.00949
# momentum: 0.86071
# weight_decay: 0.00048
# warmup_epochs: 2.18848
# box: 0.16628
# cls: 0.46895

# %%
print(result_grid)
# Out:
# None
