# %%
# %pip install ultralytics pandas matplotlib

# %%
from ultralytics import YOLO
import pandas as pd
import matplotlib.pyplot as plt

# %%
ROOT_FOLDER = "."
DATASET_FOLDER = f"{ROOT_FOLDER}/datasets"
MODEL_FOLDER = f"{ROOT_FOLDER}/model"
RUNS_FOLDER = f"{ROOT_FOLDER}/runs"

BASE_MODEL = 'yolo11n.pt'
MODEL_NAME = 'sheep-detector+preprocessing+augmentation+no-patience.pt'

# %%
model = YOLO(f"{MODEL_FOLDER}/{BASE_MODEL}")

results = model.train(
    # Tuned parameters
    lr0=0.00949,
    momentum=0.86071,
    weight_decay=0.00048,
    warmup_epochs=2.18848,
    box=0.16628,
    cls=0.46895,

    # Other parameters
    data="sheep.yaml", 
    epochs=100,
    batch=16,   
    patience=0,          
    imgsz=640,           
    name="sheep-detector",   
    verbose=False
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.145 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.113 🚀 Python-3.12.10 torch-2.6.0 CPU (Apple M3 Max)
# engine/trainer: task=detect, mode=train, model=../model/yolo11n.pt, data=../sheep.yaml, epochs=100, time=None, patience=0, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=sheep-detector8, exist_ok=False, pretrained=True, optimizer=auto, verbose=False, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.00949, lrf=0.01, momentum=0.86071, weight_decay=0.00048, warmup_epochs=2.18848, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.16628, cls=0.46895, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, cfg=None, tracker=botsort.yaml, save_dir=/Users/david/School/repositories/Sheep-Detector/runs/detect/sheep-detector8
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/School/repositories/Sheep-Detector/venv/lib/python3.12/site-packages/ultralytics/engine/trainer.py:581, in BaseTrainer.get_dataset(self)
#     575 elif self.args.data.split(".")[-1] in {"yaml", "yml"} or self.args.task in {
#     576     "detect",
#     577     "segment",
#     578     "pose",
#     579     "obb",
#     580 }:
# --> 581     data = check_det_dataset(self.args.data)
#     582     if "yaml_file" in data:
#
# File ~/School/repositories/Sheep-Detector/venv/lib/python3.12/site-packages/ultralytics/data/utils.py:454, in check_det_dataset(dataset, autodownload)
#     453     m += f"\nNote dataset download directory is '{DATASETS_DIR}'. You can update this in '{SETTINGS_FILE}'"
# --> 454     raise FileNotFoundError(m)
#     455 t = time.time()
#
# FileNotFoundError: Dataset '../sheep.yaml' images not found, missing path '/Users/david/School/repositories/datasets/dataset/val'
# Note dataset download directory is '/Users/david/School/repositories/datasets'. You can update this in '/Users/david/Library/Application Support/Ultralytics/settings.json'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 3
#       1 model = YOLO(f"{MODEL_FOLDER}/{BASE_MODEL}")
# ----> 3 results = model.train(
#       4     # Tuned parameters
#       5     lr0=0.00949,
#       6     momentum=0.86071,
#       7     weight_decay=0.00048,
#       8     warmup_epochs=2.18848,
#       9     box=0.16628,
#      10     cls=0.46895,
#      11
#      12     # Other parameters
#      13     data="../sheep.yaml",
#      14     epochs=100,
#      15     batch=16,
#      16     patience=0,
#      17     imgsz=640,
#      18     name="sheep-detector",
#      19     verbose=False
#      20 )
#
# File ~/School/repositories/Sheep-Detector/venv/lib/python3.12/site-packages/ultralytics/engine/model.py:784, in Model.train(self, trainer, **kwargs)
#     781 if args.get("resume"):
#     782     args["resume"] = self.ckpt_path
# --> 784 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     785 if not args.get("resume"):  # manually set model only if not resuming
#     786     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File ~/School/repositories/Sheep-Detector/venv/lib/python3.12/site-packages/ultralytics/engine/trainer.py:137, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     135 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     136 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 137     self.trainset, self.testset = self.get_dataset()
#     138 self.ema = None
#     140 # Optimization utils init
#
# File ~/School/repositories/Sheep-Detector/venv/lib/python3.12/site-packages/ultralytics/engine/trainer.py:585, in BaseTrainer.get_dataset(self)
#     583             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     584 except Exception as e:
# --> 585     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     586 self.data = data
#     587 if self.args.single_cls:
#
# RuntimeError: Dataset '../sheep.yaml' error ❌ Dataset '../sheep.yaml' images not found, missing path '/Users/david/School/repositories/datasets/dataset/val'
# Note dataset download directory is '/Users/david/School/repositories/datasets'. You can update this in '/Users/david/Library/Application Support/Ultralytics/settings.json'

# %%
final_model_path = f"{MODEL_FOLDER}/{MODEL_NAME}"
model.save(final_model_path)
print(f"Saved trained model to {final_model_path}")
# Out:
# Saved trained model to ../model/sheep-detector+preprocessing+augmentation+no-patience.pt

# %%
df = pd.read_csv(f"{RUNS_FOLDER}/detect/sheep-detector4/results.csv")
df.columns = df.columns.str.strip()

df
# Out:
#     epoch       time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1    3.47279         0.05994         3.95765         1.43113
# 1       2    5.99445         0.05731         2.11893         1.30410
# 2       3    8.44698         0.04995         1.89433         1.18575
# 3       4   10.82840         0.04724         1.90273         1.15930
# 4       5   13.18580         0.04824         1.73398         1.16431
# ..    ...        ...             ...             ...             ...
# 95     96  248.73600         0.02290         0.52502         0.89748
# 96     97  251.33700         0.02264         0.50598         0.89182
# 97     98  253.74400         0.02096         0.48801         0.88809
# 98     99  256.04400         0.02180         0.49927         0.88119
# 99    100  258.35500         0.02152         0.48888         0.89200
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                0.00870            0.75887           0.16244
# 1                0.00878            0.76596           0.01571
# 2                0.00927            0.80851           0.02137
# 3                0.01024            0.89362           0.13946
# 4                0.01000            0.87234           0.04586
# ..                   ...                ...               ...
# 95               0.97162            0.95745           0.98866
# 96               0.95074            0.95817           0.98428
# 97               0.95489            0.95745           0.98562
# 98               0.95102            0.95745           0.98523
# 99               0.95726            0.95310           0.98620
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0               0.03074       0.05217       3.66526       1.27464  0.000220
# 1               0.00572       0.04894       3.76023       1.22482  0.000455
# 2               0.00807       0.04238       3.53793       1.10329  0.000686
# 3               0.02763       0.04108       3.44303       1.06633  0.000912
# 4               0.01165       0.05029       3.43286       1.20450  0.001133
# ..                  ...           ...           ...           ...       ...
# 95              0.69325       0.02079       0.46688       0.86319  0.000119
# 96              0.69165       0.02144       0.47527       0.86821  0.000099
# 97              0.68000       0.02281       0.48798       0.88050  0.000079
# 98              0.65891       0.02453       0.50178       0.89692  0.000060
# 99              0.65384       0.02550       0.51084       0.90573  0.000040
#
#       lr/pg1    lr/pg2
# 0   0.000220  0.000220
# 1   0.000455  0.000455
# 2   0.000686  0.000686
# 3   0.000912  0.000912
# 4   0.001133  0.001133
# ..       ...       ...
# 95  0.000119  0.000119
# 96  0.000099  0.000099
# 97  0.000079  0.000079
# 98  0.000060  0.000060
# 99  0.000040  0.000040
#
# [100 rows x 15 columns]

# %%
# Chart 1: Validation Box and Class Loss
plt.figure(figsize=(10, 5))
plt.plot(df['epoch'], df['val/box_loss'], label='Box Loss')
plt.plot(df['epoch'], df['val/cls_loss'], label='Class Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Box and Class Loss Over Epochs (lower is better)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
